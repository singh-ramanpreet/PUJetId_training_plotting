# %%
import ROOT
from pyroot_cms_scripts import CMS_style, CMS_text
# Out:
# Welcome to JupyROOT 6.18/00

# %%
ROOT.TGaxis().SetMaxDigits(4)
CMS_style.SetTitleYOffset(1.0)
CMS_style.cd()
ROOT.gROOT.ForceStyle()

data_file = ROOT.TFile.Open("hists_2018/double_muon_data_2018full.root")
mc_file = ROOT.TFile.Open("hists_2018/dy_amcatnlo_ext2_20_mc_2018full.root")

title = ";#Delta#phi (Z, jet);p^{T}_{jet} / p^{T}_{Z}"

data_dphi_zj_ptj_z = data_file.Get("data_dphi_zj_ptj_z")
data_dphi_zj_ptj_z.SetTitle(title)
prompt_dphi_zj_ptj_z = mc_file.Get("prompt_dphi_zj_ptj_z")
prompt_dphi_zj_ptj_z.SetTitle(title)
pileup_dphi_zj_ptj_z = mc_file.Get("pileup_dphi_zj_ptj_z")
pileup_dphi_zj_ptj_z.SetTitle(title)

# %%
plot = """
canvas = ROOT.TCanvas("", "", 700, 600)
canvas.SetRightMargin(0.13)
data_dphi_zj_ptj_z.Draw("colz")
canvas.SetLogz(1)
canvas.Draw()
canvas.Print("plots_amcatnlo_2018/data_dphi_zj_ptj_z.pdf")
"""

# %%
exec(plot)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name:
# Info in <TCanvas::Print>: pdf file plots_amcatnlo_2018/data_dphi_zj_ptj_z.pdf has been created

# %%
exec(plot.replace("data", "prompt"))
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name:
# Info in <TCanvas::Print>: pdf file plots_amcatnlo_2018/prompt_dphi_zj_ptj_z.pdf has been created

# %%
exec(plot.replace("data", "pileup"))
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name:
# Info in <TCanvas::Print>: pdf file plots_amcatnlo_2018/pileup_dphi_zj_ptj_z.pdf has been created
